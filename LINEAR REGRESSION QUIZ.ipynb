# %%
import numpy as np  #mathematical computation
import pandas as pd  #data manipulation
import matplotlib.pyplot as plt # data visualisation
import seaborn as sns # data visualisation
import warnings # removing warning
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('data(LR).csv')

# %%
housing=pd.read_csv('housing(LR).csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.shape
# Out:
# (30, 2)

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe().round().T
# Out:
#                  count     mean      std      min      25%      50%       75%  \
# YearsExperience   30.0      5.0      3.0      1.0      3.0      5.0       8.0
# Salary            30.0  76003.0  27414.0  37731.0  56721.0  65237.0  100545.0
#
#                       max
# YearsExperience      10.0
# Salary           122391.0

# %%
data.describe(include='all').T
# Out:
#                  count          mean           std      min       25%  \
# YearsExperience   30.0      5.313333      2.837888      1.1      3.20
# Salary            30.0  76003.000000  27414.429785  37731.0  56720.75
#
#                      50%        75%       max
# YearsExperience      4.7       7.70      10.5
# Salary           65237.0  100544.75  122391.0

# %%
housing.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
housing.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
housing.shape
# Out:
# (21613, 21)

# %%
housing.ndim
# Out:
# 2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
housing.describe().round().T
# Out:
#                  count          mean           std        min           25%  \
# id             21613.0  4.580302e+09  2.876566e+09  1000102.0  2.123049e+09
# price          21613.0  5.400880e+05  3.671270e+05    75000.0  3.219500e+05
# bedrooms       21613.0  3.000000e+00  1.000000e+00        0.0  3.000000e+00
# bathrooms      21613.0  2.000000e+00  1.000000e+00        0.0  2.000000e+00
# sqft_living    21613.0  2.080000e+03  9.180000e+02      290.0  1.427000e+03
# sqft_lot       21613.0  1.510700e+04  4.142100e+04      520.0  5.040000e+03
# floors         21613.0  1.000000e+00  1.000000e+00        1.0  1.000000e+00
# waterfront     21613.0  0.000000e+00  0.000000e+00        0.0  0.000000e+00
# view           21613.0  0.000000e+00  1.000000e+00        0.0  0.000000e+00
# condition      21613.0  3.000000e+00  1.000000e+00        1.0  3.000000e+00
# grade          21613.0  8.000000e+00  1.000000e+00        1.0  7.000000e+00
# ...

# %%
housing.describe(include='all').T
# Out:
#                  count unique              top freq               mean  \
# id             21613.0    NaN              NaN  NaN  4580301520.864988
# date             21613    372  20140623T000000  142                NaN
# price          21613.0    NaN              NaN  NaN      540088.141905
# bedrooms       21613.0    NaN              NaN  NaN           3.370842
# bathrooms      21613.0    NaN              NaN  NaN           2.114757
# sqft_living    21613.0    NaN              NaN  NaN        2079.899736
# sqft_lot       21613.0    NaN              NaN  NaN       15106.967566
# floors         21613.0    NaN              NaN  NaN           1.494309
# waterfront     21613.0    NaN              NaN  NaN           0.007542
# view           21613.0    NaN              NaN  NaN           0.234303
# condition      21613.0    NaN              NaN  NaN            3.40943
# grade          21613.0    NaN              NaN  NaN           7.656873
# ...

# %%
#SALARY DISTRIBUTION
sns.distplot(x=data['Salary'])
plt.xlabel('Salary')
plt.ylabel('Years of experience')
plt.show()

# %%
plt.subplots(1,figsize=(30,5))
plt.subplot(1,1,1)
sns.countplot(x=data['Salary'])
plt.xlabel('Salary')
plt.ylabel('Experience')
# Out:
# Text(0, 0.5, 'Experience')

# %%
Sample = np.array([42,61,39,70,8,30,52,28,95,86,35,77,80,86,1,84,90,57,45,6,1,56,60,83,24,63,93,59,92,53])

# %%
Sample
# Out:
# array([42, 61, 39, 70,  8, 30, 52, 28, 95, 86, 35, 77, 80, 86,  1, 84, 90,
#        57, 45,  6,  1, 56, 60, 83, 24, 63, 93, 59, 92, 53])

# %%
Sample.std()
# Out:
# 28.49491182649983

# %%
Sample.var()
# Out:
# 811.9599999999999

# %%
import numpy as np

# Given array
array = np.array([17, 27, 80, 39, 72, 95, 52, 85, 8, 64, 36, 15, 62, 76, 66, 67, 59, 92])

# Calculate the range
range_value = np.max(array) - np.min(array)

# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = np.percentile(array, 25)
Q3 = np.percentile(array, 75)

# Calculate the IQR
IQR = Q3 - Q1

range_value, IQR
# Out:
# (87, 38.25)

# %%
Sample1 = np.array([88, 92, 84, 64, 96, 97, 67, 97, 96, 99, 115, 119, 119, 129, 130, 142, 102, 123, 134, 105])
Sample1
# Out:
# array([ 88,  92,  84,  64,  96,  97,  67,  97,  96,  99, 115, 119, 119,
#        129, 130, 142, 102, 123, 134, 105])

# %%
Sample1.mean()
# Out:
# 104.9
